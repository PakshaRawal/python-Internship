# %%
print("hello")
# Out:
# hello

# %% [markdown]
# ## hello

# %% [markdown]
# - hii

# %%
import numpy as np

# %%
myarr = np.array([-128,127,4,5], np.int8)

# %%
print(myarr)
print(myarr.ndim)
# Out:
# [-128  127    4    5]
# 1

# %%
agesArr = np.array([[1,2,3]])

# %%
print(agesArr.ndim)
agesArr.shape
# Out:
# 2
# (1, 3)

# %%
heightsArr = np.array([[[1,2,3,4], [5,6,7,8], [7,8,9,10]]])

# %%
print(heightsArr)
heightsArr.ndim
heightsArr.shape
# Out:
# [[[ 1  2  3  4]
#   [ 5  6  7  8]
#   [ 7  8  9 10]]]
# (1, 3, 4)
